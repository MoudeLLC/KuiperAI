# %% [markdown]
# # KuiperAI Model Initialization on Google Colab
# Run this notebook on Google Colab with GPU enabled
#
# **Steps:**
# 1. Upload this notebook to Google Colab
# 2. Go to Runtime → Change runtime type → Select GPU (T4)
# 3. Run all cells

# %%
# Check GPU availability
# !nvidia-smi

# %%
# Install dependencies
# !pip install transformers torch accelerate -q

# %%
# Clone KuiperAI repository
# !git clone https://github.com/MoudeLLC/KuiperAI.git
# %cd KuiperAI/knowledge/official/scripts

# %%
# Run initialization with choice 1 (from scratch) and choice 2 (medium model)
# !echo -e "1\n2" | python3 initialize_pretrained.py

# %%
# Download the initialized model
# !zip -r kuiperai_model.zip ../train/pre/
from google.colab import files
files.download('kuiperai_model.zip')
